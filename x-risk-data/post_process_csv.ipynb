# %%
import pandas as pd

# %%
# define manually!
CLUSTER_TOPICS = {
        0: 'ai: agi',
        1: 'ai: safety',
        2: 'ai: model capabilities',
        3: 'rationality: mental health & productivity', 
        4: 'economics: macroeconomics',
        5: 'nuclear preparedness',
        6: 'philosophy: consciousness',
        7: 'ai: neural network circuits', 
        8: 'ai: alignment',
        9: 'rationality: abstract world problems',
        10: 'rationality: concrete world problems',
        11: 'ai: mech interp',
        12: 'community: personal stories',
        13: 'community: lesswrong auditing',
        14: 'ai: reinforcement learning',
        15: 'ai: model training & optimization',
        16: 'bio: covid',
        17: 'ai: tech giants',
        18: 'bio: evolution',
        19: 'economics: decision theory',
        20: 'philosophy: simulations',
        21: 'ai: model reasoning',
        22: 'community: media and media threads',
        23: 'ai: research',
        24: 'rationality: forecasting',
        25: 'miscelleanous',
        26: 'rationality: social problems',
        27: 'ai: alignment problems', 
        28: 'philosophy: moral philosophy',
        29: 'community: effective altruism',
        30: 'ai: scaling',
        31: 'ai: probability theory', 
        32: 'economics: decision theory',
        33: 'economics: game theory',
        34: 'ai: data & information',
        35: 'rationality: parenting',
    }

# %%
"""
Append topic columns (cluster index + label) to LW CSV files 
using clustering results.
"""
clustering_results_csv = 'results/blog_lda_results_36.csv'

print(f"Loading clustering results from {clustering_results_csv}...")
results_df = pd.read_csv(clustering_results_csv)
print(f"Loaded {len(results_df)} clustered posts")

updated_files = 0
total_matches = 0

# Add human-readable topic labels
results_df["topic_label"] = results_df["dominant_topic"].map(CLUSTER_TOPICS)

# Process each LW CSV file separately
for file_path, group in results_df.groupby("file"):
    print(f"\nProcessing {file_path}...")

    try:
        # Extract just the filename and build correct path
        import os
        filename = os.path.basename(file_path)  # Gets just "2025-01.csv"
        correct_file_path = f'lw_csv_cleaned/{file_path.split("lw_csv_cleaned/")[1]}'  # Gets "lw_csv_cleaned/2025/2025-01.csv"
        
        # Load the original file with correct path
        df = pd.read_csv(correct_file_path)
        original_count = len(df)

        merge_data = group[["title", "dominant_topic", "topic_label"]]
        merged = df.merge(merge_data, how="left", on="title")

        # Rename cluster column
        merged.rename(columns={"dominant_topic": "topic_cluster_id"}, inplace=True)

        # Fill none values
        merged["topic_cluster_id"] = merged["topic_cluster_id"].fillna(-1).astype(int)
        merged["topic_label"] = merged["topic_label"].fillna("No Topic")
        
        mask = (merged["topic_label"] == "No Topic") & (
            merged["cleaned_htmlBody"].str[:50].str.lower().str.contains("meetup", na=False)
            | merged["title"].str.lower().str.contains("meetup", na=False)
        )
        merged.loc[mask, "topic_label"] = "community: meetup"
        merged.loc[mask, "topic_cluster_id"] = -2  # special cluster id for rule-based label

        # Save back with proper filename
        output_path = f'lw_csv_cleaned_topic/{file_path.split("lw_csv_cleaned/")[1]}'
        
        # Make sure output directory exists
        os.makedirs(os.path.dirname(output_path), exist_ok=True)
        
        merged.to_csv(output_path, index=False)

        matches = (merged["topic_cluster_id"] != -1).sum()
        updated_files += 1
        total_matches += matches

        print(f"  SUCCESS: {matches}/{original_count} posts matched")

    except Exception as e:
        print(f'Error processing {file_path}: {e}')
        print(f'Error type: {type(e).__name__}')
# Out:
# Loading clustering results from results/blog_lda_results_36.csv...
# Loaded 31405 clustered posts
#
# Processing x-risk-data/lw_csv_cleaned/2016/2016-01.csv...
#   SUCCESS: 132/122 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2016/2016-02.csv...
#   SUCCESS: 104/105 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2016/2016-03.csv...
#   SUCCESS: 101/101 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2016/2016-04.csv...
#   SUCCESS: 107/107 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2016/2016-05.csv...
#   SUCCESS: 79/79 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2016/2016-06.csv...
#   SUCCESS: 103/104 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2016/2016-07.csv...
#   SUCCESS: 91/93 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2016/2016-08.csv...
#   SUCCESS: 81/87 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2016/2016-09.csv...
#   SUCCESS: 127/114 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2016/2016-10.csv...
#   SUCCESS: 106/107 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2016/2016-11.csv...
#   SUCCESS: 124/134 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2016/2016-12.csv...
#   SUCCESS: 160/163 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2017/2017-01.csv...
#   SUCCESS: 183/182 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2017/2017-02.csv...
#   SUCCESS: 154/147 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2017/2017-03.csv...
#   SUCCESS: 171/169 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2017/2017-04.csv...
#   SUCCESS: 118/117 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2017/2017-05.csv...
#   SUCCESS: 137/145 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2017/2017-06.csv...
#   SUCCESS: 131/121 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2017/2017-07.csv...
#   SUCCESS: 79/80 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2017/2017-08.csv...
#   SUCCESS: 71/71 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2017/2017-09.csv...
#   SUCCESS: 130/126 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2017/2017-10.csv...
#   SUCCESS: 235/226 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2017/2017-11.csv...
#   SUCCESS: 174/163 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2017/2017-12.csv...
#   SUCCESS: 125/127 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2018/2018-01.csv...
#   SUCCESS: 154/160 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2018/2018-02.csv...
#   SUCCESS: 153/152 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2018/2018-03.csv...
#   SUCCESS: 196/193 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2018/2018-04.csv...
#   SUCCESS: 162/168 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2018/2018-05.csv...
#   SUCCESS: 152/158 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2018/2018-06.csv...
#   SUCCESS: 123/130 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2018/2018-07.csv...
#   SUCCESS: 202/213 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2018/2018-08.csv...
#   SUCCESS: 116/119 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2018/2018-09.csv...
#   SUCCESS: 108/115 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2018/2018-10.csv...
#   SUCCESS: 139/140 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2018/2018-11.csv...
#   SUCCESS: 149/154 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2018/2018-12.csv...
#   SUCCESS: 135/140 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2019/2019-01.csv...
#   SUCCESS: 183/196 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2019/2019-02.csv...
#   SUCCESS: 169/176 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2019/2019-03.csv...
#   SUCCESS: 164/171 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2019/2019-04.csv...
#   SUCCESS: 134/139 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2019/2019-05.csv...
#   SUCCESS: 172/182 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2019/2019-06.csv...
#   SUCCESS: 154/163 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2019/2019-07.csv...
#   SUCCESS: 166/174 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2019/2019-08.csv...
#   SUCCESS: 205/213 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2019/2019-09.csv...
#   SUCCESS: 259/261 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2019/2019-10.csv...
#   SUCCESS: 206/210 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2019/2019-11.csv...
#   SUCCESS: 189/192 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2019/2019-12.csv...
#   SUCCESS: 250/259 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2020/2020-01.csv...
#   SUCCESS: 215/222 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2020/2020-02.csv...
#   SUCCESS: 198/202 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2020/2020-03.csv...
#   SUCCESS: 345/355 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2020/2020-04.csv...
#   SUCCESS: 256/270 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2020/2020-05.csv...
#   SUCCESS: 231/236 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2020/2020-06.csv...
#   SUCCESS: 233/241 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2020/2020-07.csv...
#   SUCCESS: 296/299 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2020/2020-08.csv...
#   SUCCESS: 242/250 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2020/2020-09.csv...
#   SUCCESS: 216/217 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2020/2020-10.csv...
#   SUCCESS: 233/239 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2020/2020-11.csv...
#   SUCCESS: 270/277 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2020/2020-12.csv...
#   SUCCESS: 296/305 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2021/2021-01.csv...
#   SUCCESS: 300/306 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2021/2021-02.csv...
#   SUCCESS: 253/263 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2021/2021-03.csv...
#   SUCCESS: 307/312 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2021/2021-04.csv...
#   SUCCESS: 257/267 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2021/2021-05.csv...
#   SUCCESS: 245/255 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2021/2021-06.csv...
#   SUCCESS: 240/253 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2021/2021-07.csv...
#   SUCCESS: 217/221 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2021/2021-08.csv...
#   SUCCESS: 412/427 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2021/2021-09.csv...
#   SUCCESS: 282/288 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2021/2021-10.csv...
#   SUCCESS: 308/318 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2021/2021-11.csv...
#   SUCCESS: 245/252 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2021/2021-12.csv...
#   SUCCESS: 303/313 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2022/2022-01.csv...
#   SUCCESS: 270/277 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2022/2022-02.csv...
#   SUCCESS: 287/298 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2022/2022-03.csv...
#   SUCCESS: 307/313 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2022/2022-04.csv...
#   SUCCESS: 509/520 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2022/2022-05.csv...
#   SUCCESS: 309/315 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2022/2022-06.csv...
#   SUCCESS: 417/429 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2022/2022-07.csv...
#   SUCCESS: 333/341 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2022/2022-08.csv...
#   SUCCESS: 526/544 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2022/2022-09.csv...
#   SUCCESS: 406/417 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2022/2022-10.csv...
#   SUCCESS: 381/392 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2022/2022-11.csv...
#   SUCCESS: 372/389 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2022/2022-12.csv...
#   SUCCESS: 484/506 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2023/2023-01.csv...
#   SUCCESS: 452/476 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2023/2023-02.csv...
#   SUCCESS: 466/496 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2023/2023-03.csv...
#   SUCCESS: 589/613 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2023/2023-04.csv...
#   SUCCESS: 636/658 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2023/2023-05.csv...
#   SUCCESS: 502/515 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2023/2023-06.csv...
#   SUCCESS: 399/412 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2023/2023-07.csv...
#   SUCCESS: 409/421 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2023/2023-08.csv...
#   SUCCESS: 508/521 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2023/2023-09.csv...
#   SUCCESS: 334/352 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2023/2023-10.csv...
#   SUCCESS: 389/407 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2023/2023-11.csv...
#   SUCCESS: 438/453 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2023/2023-12.csv...
#   SUCCESS: 366/371 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2024/2024-01.csv...
#   SUCCESS: 362/371 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2024/2024-02.csv...
#   SUCCESS: 320/333 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2024/2024-03.csv...
#   SUCCESS: 522/532 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2024/2024-04.csv...
#   SUCCESS: 335/344 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2024/2024-05.csv...
#   SUCCESS: 363/375 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2024/2024-06.csv...
#   SUCCESS: 346/355 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2024/2024-07.csv...
#   SUCCESS: 361/369 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2024/2024-08.csv...
#   SUCCESS: 492/500 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2024/2024-09.csv...
#   SUCCESS: 331/335 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2024/2024-10.csv...
#   SUCCESS: 365/378 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2024/2024-11.csv...
#   SUCCESS: 353/363 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2024/2024-12.csv...
#   SUCCESS: 379/395 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2025/2025-01.csv...
#   SUCCESS: 473/493 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2025/2025-02.csv...
#   SUCCESS: 428/438 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2025/2025-03.csv...
#   SUCCESS: 621/646 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2025/2025-04.csv...
#   SUCCESS: 485/516 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2025/2025-05.csv...
#   SUCCESS: 465/478 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2025/2025-06.csv...
#   SUCCESS: 434/445 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2025/2025-07.csv...
#   SUCCESS: 454/473 posts matched
#
# Processing x-risk-data/lw_csv_cleaned/2025/2025-08.csv...
#   SUCCESS: 437/449 posts matched
