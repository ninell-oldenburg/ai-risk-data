# %%
import pandas as pd

# %%
# define manually!
CLUSTER_TOPICS = {
        0: 'the universe, simulation, and physics',
        1: 'ai risk',
        2: 'stories',
        3: 'micro economics', 
        4: 'doing good better',
        5: 'miscellanous', # i don't know about this one
        6: 'reinforcement learning',
        7: 'agi, superintelligence', 
        8: 'llms',
        9: 'religion and social ai', # i don't know about this one
        10: 'lesswrong community posts',
        11: 'acx meetups',
        12: 'strategy online games',
        13: 'medicine',
        14: 'social affairs',
        15: 'ai alignment',
        16: '???',
        17: 'legal policy',
        18: 'decision theory',
        19: 'agent foundations',
        20: 'productivity',
        21: 'machine & deep learning',
        22: '???',
        23: 'rationality',
        24: 'reinforcment learning',
        25: 'bias & beliefs',
        26: 'tech giants',
        27: 'rationality & productivity', 
        28: 'mix of others',
        29: 'nuclear risk',
        30: 'ai safety research',
        31: 'mech interp', 
        32: 'bayesain probability, forecasting',
        33: 'rationality',
        34: 'game theory', # blurry though!
        35: 'ai evals',
        36: 'brain, mind & consciousness',
        37: 'values and ethics',
        38: 'covid',
        39: 'miscelleanous'
    }

# %%
"""
Append topic columns (cluster index + label) to LW CSV files 
using clustering results.
"""
clustering_results_csv = 'results/blog_lda_results_40.csv'

print(f"Loading clustering results from {clustering_results_csv}...")
results_df = pd.read_csv(clustering_results_csv)
print(f"Loaded {len(results_df)} clustered posts")

updated_files = 0
total_matches = 0

# Add human-readable topic labels
results_df["topic_label"] = results_df["cluster"].map(CLUSTER_TOPICS)

# Process each LW CSV file separately
for file_path, group in results_df.groupby("file"):
    print(f"\nProcessing {file_path}...")

    try:
        # Load the original file
        df = pd.read_csv(file_path)
        original_count = len(df)

        merge_data = group[["title", "cluster", "topic_label"]]
        merged = df.merge(
            merge_data,
            how="left",
            on="title"
        )

        # Rename cluster column
        merged.rename(columns={"cluster": "topic_cluster_id"}, inplace=True)

        # Fill none values
        merged["topic_cluster_id"] = merged["topic_cluster_id"].fillna(-1).astype(int)
        merged["topic_label"] = merged["topic_label"].fillna("No Topic")

        # Save back
        merged.to_csv(file_path, index=False)

        matches = (merged["topic_cluster_id"] != -1).sum()
        updated_files += 1
        total_matches += matches

        print(f"  SUCCESS: {matches}/{original_count} posts matched")

    except:
        print(f'Error: {KeyError}')
# Out:
# Loading clustering results from blog_clustering_results_25.csv...
# Loaded 33406 clustered posts
#
# Processing lw_csv/2016/2016-01.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2016/2016-02.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2016/2016-03.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2016/2016-04.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2016/2016-05.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2016/2016-06.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2016/2016-07.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2016/2016-08.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2016/2016-09.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2016/2016-10.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2016/2016-11.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2016/2016-12.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2017/2017-01.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2017/2017-02.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2017/2017-03.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2017/2017-04.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2017/2017-05.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2017/2017-06.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2017/2017-07.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2017/2017-08.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2017/2017-09.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2017/2017-10.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2017/2017-11.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2017/2017-12.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2018/2018-01.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2018/2018-02.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2018/2018-03.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2018/2018-04.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2018/2018-05.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2018/2018-06.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2018/2018-07.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2018/2018-08.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2018/2018-09.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2018/2018-10.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2018/2018-11.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2018/2018-12.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2019/2019-01.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2019/2019-02.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2019/2019-03.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2019/2019-04.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2019/2019-05.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2019/2019-06.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2019/2019-07.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2019/2019-08.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2019/2019-09.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2019/2019-10.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2019/2019-11.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2019/2019-12.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2020/2020-01.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2020/2020-02.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2020/2020-03.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2020/2020-04.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2020/2020-05.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2020/2020-06.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2020/2020-07.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2020/2020-08.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2020/2020-09.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2020/2020-10.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2020/2020-11.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2020/2020-12.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2021/2021-01.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2021/2021-02.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2021/2021-03.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2021/2021-04.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2021/2021-05.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2021/2021-06.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2021/2021-07.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2021/2021-08.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2021/2021-09.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2021/2021-10.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2021/2021-11.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2021/2021-12.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2022/2022-01.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2022/2022-02.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2022/2022-03.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2022/2022-04.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2022/2022-05.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2022/2022-06.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2022/2022-07.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2022/2022-08.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2022/2022-09.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2022/2022-10.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2022/2022-11.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2022/2022-12.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2023/2023-01.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2023/2023-02.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2023/2023-03.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2023/2023-04.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2023/2023-05.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2023/2023-06.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2023/2023-07.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2023/2023-08.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2023/2023-09.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2023/2023-10.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2023/2023-11.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2023/2023-12.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2024/2024-01.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2024/2024-02.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2024/2024-03.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2024/2024-04.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2024/2024-05.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2024/2024-06.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2024/2024-07.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2024/2024-08.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2024/2024-09.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2024/2024-10.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2024/2024-11.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2024/2024-12.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2025/2025-01.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2025/2025-02.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2025/2025-03.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2025/2025-04.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2025/2025-05.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2025/2025-06.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2025/2025-07.csv...
# Error: <class 'KeyError'>
#
# Processing lw_csv/2025/2025-08.csv...
# Error: <class 'KeyError'>
